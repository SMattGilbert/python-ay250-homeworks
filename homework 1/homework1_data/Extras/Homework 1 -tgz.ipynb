# %%
import tarfile
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
tar=tarfile.open("homework1_data.tgz")
tar.getmembers()
# Out:
# [<TarInfo './._Data' at 0xfb309dd110>,
#  <TarInfo 'Data' at 0xfb309dd1d8>,
#  <TarInfo 'Data/._im2-0.png' at 0xfb309dd2a0>,
#  <TarInfo 'Data/im2-0.png' at 0xfb309dd368>,
#  <TarInfo 'Data/._im2-1.png' at 0xfb309dd430>,
#  <TarInfo 'Data/im2-1.png' at 0xfb309dd4f8>,
#  <TarInfo 'Data/._im2-10.png' at 0xfb309dd5c0>,
#  <TarInfo 'Data/im2-10.png' at 0xfb309dd688>,
#  <TarInfo 'Data/._im2-11.png' at 0xfb309dd750>,
#  <TarInfo 'Data/im2-11.png' at 0xfb309dd818>,
#  <TarInfo 'Data/._im2-12.png' at 0xfb309dd8e0>,
#  <TarInfo 'Data/im2-12.png' at 0xfb309dd9a8>,
#  <TarInfo 'Data/._im2-13.png' at 0xfb309dda70>,
#  <TarInfo 'Data/im2-13.png' at 0xfb309ddb38>,
#  <TarInfo 'Data/._im2-14.png' at 0xfb309ddc00>,
#  <TarInfo 'Data/im2-14.png' at 0xfb309ddcc8>,
#  <TarInfo 'Data/._im2-15.png' at 0xfb309ddd90>,
#  <TarInfo 'Data/im2-15.png' at 0xfb309dde58>,
#  <TarInfo 'Data/._im2-16.png' at 0xfb309ddf20>,
#  <TarInfo 'Data/im2-16.png' at 0xfb309e4048>,
# ...

# %%
tar.extractfile("Data/._im2-0.png")
# Out:
# <ExFileObject name='homework1_data.tgz'>

# %%
files = tar.getmembers()
file = tar.extractfile(files[-5]) # if your docs.json is in the 0th position
file.readlines()
# Out:
# [b'\x89PNG\r\n',
#  b'\x1a\n',
# ...
